# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd

# %% [markdown]
# #1 Initialisation

# %%
# parametres de references
K_x, K_y, sigma_x, sigma_y, pho = 0.07173132, 0.08930784, 0.09465584, 0.094675523, -0.999318


def X_ZC(T, para):
  K_x, K_y, sigma_x, sigma_y, pho = para
  return sigma_x * (1 - np.exp(-K_x*T)) / (K_x * T)

def X_FWD(T,para):
  K_x, K_y, sigma_x, sigma_y, pho = para
  return sigma_x * np.exp(-K_x*T)

def Y_ZC(T,para):
  K_x, K_y, sigma_x, sigma_y, pho = para
  return sigma_y * (1 - np.exp(-K_y*T)) / (K_y * T)

def Y_FWD(T,para):
  K_x, K_y, sigma_x, sigma_y, pho = para
  return sigma_y * np.exp(-K_y*T)

def cov(X,Y,T_i, T_j,para):
  K_x, K_y, sigma_x, sigma_y, pho = para
  a = X(T_i,para)*X(T_j,para) + Y(T_i,para)*Y(T_j,para)
  b = X(T_i,para)*Y(T_j,para) + X(T_j,para)*Y(T_i,para)
  return a + pho * b

def corr(X,Y,T_i, T_j,para):
  K_x, K_y, sigma_x, sigma_y, pho = para
  a = X(T_i,para)**2 + Y(T_i,para)**2 + 2*pho*X(T_i,para)*Y(T_i,para)
  b = X(T_j,para)**2 + Y(T_j,para)**2 + 2*pho*X(T_j,para)*Y(T_j,para)
  return cov(X,Y,T_i, T_j,para) / np.sqrt(a*b)

# %%
np.random.seed(42)

def para(N):
  min = [0.02391044, 0.02976928, 0.03155195, 0.03155851, -0.999318]
  max = [0.1195522, 0.1488464, 0.15775973, 0.15779254, 0.999318]

  result = np.zeros((N,5))
  for i in range(5):
    result[:,i] = np.random.uniform(min[i], max[i], N)

  return result

name = ['K_x', 'K_y', 'sigma_x', 'sigma_y', 'pho']
N = 10000
result = para(N)
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i in range(5):
    sns.histplot(result[:,i], kde=True, bins=20, ax=axes[i])
    axes[i].set_title("Distribution de {}".format(name[i]))

plt.tight_layout()
plt.show()

# %% [markdown]
# #2 Methode Indirect

# %% [markdown]
# ***2.1: Cov ZC***

# %%
maturity_cov = []
for i in range(1,13):
  for j in range(i,13):
    maturity_cov.append([i,j])
print('nf cov:',len(maturity_cov))

maturity_corr = []
for i in range(1,12):
  for j in range(i,12):
    maturity_corr.append([i,j])
print('nf corr:',len(maturity_corr))
# Out:
# nf cov: 78
# nf corr: 66

# %%
print(result[:5,:])
a,b,c,d,e =result[0]
print(a,b,c,d,e)
# Out:
# [[ 0.05973212  0.07426135  0.12368342  0.11211407 -0.40190163]
#  [ 0.11483843  0.06941149  0.0548388   0.08953685 -0.80981178]
#  [ 0.09391963  0.05074518  0.07530058  0.15331105 -0.7467719 ]
#  [ 0.08116719  0.10208085  0.11526313  0.05920104 -0.63822218]
#  [ 0.03883234  0.08652431  0.09239538  0.10576599 -0.59228911]]
# 0.05973211615717092 0.07426135257745727 0.12368341623379375 0.11211407058823004 -0.4019016336153698

# %%
cov_test = []
corr_test = []
Para = []

for k in range(4):
    ind = np.random.randint(0, 10000)
    para = result[ind]
    Para.append(para)
    l_cov, l_corr = [], []

    for i in range(66):
      T_i, T_j = maturity_cov[i]
      T_i2, T_j2 = maturity_corr[i]
      l_cov.append(cov(X_ZC, Y_ZC, T_i, T_j, para))
      l_corr.append(corr(X_FWD, Y_FWD, T_i2, T_j2, para))

    for i in range(66,78):
      T_i, T_j = maturity_cov[i]
      l_cov.append(cov(X_ZC, Y_ZC, T_i, T_j, para))

    cov_test.append(l_cov)
    corr_test.append(l_corr)

for i, sublist in enumerate(cov_test):
    # Pour chaque liste de covariances, tracer en spécifiant les paramètres correspondants
    plt.plot(sublist, label='Paramètres : K_x={:.2f}, K_y={:.2f}, sigma_x={:.2f}, sigma_y={:.2f}, pho={:.2f}'.format(*Para[i]))
    plt.xlabel('Tenors')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

for i, sublist in enumerate(corr_test):
    plt.plot(sublist, label='Paramètres : K_x={:.2f}, K_y={:.2f}, sigma_x={:.2f}, sigma_y={:.2f}, pho={:.2f}'.format(*Para[i]))
    plt.xlabel('Tenors')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# COV

# %%
from tqdm import tqdm

X_cov = np.zeros((len(result), len(maturity_cov)))
# X_corrFWD = np.zeros((len(result), 66))
#len(result) = 10000
for k in tqdm(range(len(result))):
    para = result[k]
    l_cov = []

    for i in range(len(maturity_cov)):
      T_i, T_j = maturity_cov[i]
      l_cov.append(cov(X_ZC, Y_ZC, T_i, T_j, para))
      # l_corr.append(corr(X_FWD, Y_FWD, T_i, T_j, para))
    X_cov[k] = l_cov
    # X_corrFWD[k] = l_corr
# Out:
# 100%|██████████| 10000/10000 [00:24<00:00, 411.08it/s]

# %%
print(X_cov.shape)
# Out:
# (10000, 78)

# %%
y = result

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_cov, y, test_size=0.2, random_state=42)

# %%
X_train[:,0]
# Out:
# array([0.01838053, 0.00711996, 0.01020344, ..., 0.03082676, 0.00026888,
#        0.0064435 ])

# %%
y_train[0,:]
# Out:
# array([ 0.0976325 ,  0.04725867,  0.15136091,  0.08981906, -0.39962811])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
y_train = scaler.fit_transform(y_train)
y_test= scaler.transform(y_test)

# %%
X_train[:,0]
# Out:
# array([0.20478382, 0.07915695, 0.11355733, ..., 0.34363844, 0.00272379,
#        0.0716101 ])

# %%
y_train[0,:]
# Out:
# array([0.77102954, 0.14675095, 0.94939086, 0.46162236, 0.30004622])

# %%
print(X_train.shape)
print(y_train.shape)
print()
print(X_test.shape)
print(y_test.shape)
# Out:
# (8000, 78)
# (8000, 5)
#
# (2000, 78)
# (2000, 5)

# %%
# Définir le modèle
model = tf.keras.Sequential([
    layers.Dense(1000, activation='relu', input_shape=(78,)),  # Couche d'entrée
    layers.Dense(1500, activation='relu'),  # Première couche cachée
    layers.Dense(1000, activation='relu'),  # Deuxième couche cachée
    layers.Dropout(0.25),  # Dropout
    layers.Dense(5)  # Couche de sortie
])

# Compiler le modèle
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='mse')

# Entraîner le modèle
history = model.fit(X_train, y_train, epochs=100, batch_size=1000, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 5s 552ms/step - loss: 0.1536 - val_loss: 0.1007
# Epoch 2/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.0824 - val_loss: 0.0687
# Epoch 3/100
# 8/8 [==============================] - 4s 564ms/step - loss: 0.0665 - val_loss: 0.0605
# Epoch 4/100
# 8/8 [==============================] - 3s 387ms/step - loss: 0.0624 - val_loss: 0.0591
# Epoch 5/100
# 8/8 [==============================] - 3s 386ms/step - loss: 0.0607 - val_loss: 0.0574
# Epoch 6/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.0593 - val_loss: 0.0566
# Epoch 7/100
# 8/8 [==============================] - 4s 550ms/step - loss: 0.0587 - val_loss: 0.0562
# Epoch 8/100
# 8/8 [==============================] - 3s 383ms/step - loss: 0.0585 - val_loss: 0.0559
# Epoch 9/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0581 - val_loss: 0.0561
# Epoch 10/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0583 - val_loss: 0.0560
# Epoch 11/100
# 8/8 [==============================] - 4s 557ms/step - loss: 0.0579 - val_loss: 0.0560
# Epoch 12/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0578 - val_loss: 0.0556
# Epoch 13/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0575 - val_loss: 0.0554
# Epoch 14/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0574 - val_loss: 0.0553
# Epoch 15/100
# 8/8 [==============================] - 4s 548ms/step - loss: 0.0574 - val_loss: 0.0552
# Epoch 16/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0572 - val_loss: 0.0550
# Epoch 17/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0571 - val_loss: 0.0550
# Epoch 18/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0569 - val_loss: 0.0549
# Epoch 19/100
# 8/8 [==============================] - 4s 542ms/step - loss: 0.0570 - val_loss: 0.0550
# Epoch 20/100
# 8/8 [==============================] - 3s 387ms/step - loss: 0.0570 - val_loss: 0.0551
# Epoch 21/100
# 8/8 [==============================] - 3s 396ms/step - loss: 0.0572 - val_loss: 0.0549
# Epoch 22/100
# 8/8 [==============================] - 3s 402ms/step - loss: 0.0567 - val_loss: 0.0547
# Epoch 23/100
# 8/8 [==============================] - 4s 513ms/step - loss: 0.0569 - val_loss: 0.0554
# Epoch 24/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0570 - val_loss: 0.0552
# Epoch 25/100
# 8/8 [==============================] - 4s 578ms/step - loss: 0.0567 - val_loss: 0.0549
# Epoch 26/100
# 8/8 [==============================] - 4s 543ms/step - loss: 0.0566 - val_loss: 0.0542
# Epoch 27/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.0564 - val_loss: 0.0545
# Epoch 28/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0562 - val_loss: 0.0544
# Epoch 29/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0561 - val_loss: 0.0539
# Epoch 30/100
# 8/8 [==============================] - 4s 545ms/step - loss: 0.0559 - val_loss: 0.0542
# Epoch 31/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.0559 - val_loss: 0.0537
# Epoch 32/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0558 - val_loss: 0.0538
# Epoch 33/100
# 8/8 [==============================] - 3s 400ms/step - loss: 0.0558 - val_loss: 0.0538
# Epoch 34/100
# 8/8 [==============================] - 4s 551ms/step - loss: 0.0557 - val_loss: 0.0537
# Epoch 35/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0555 - val_loss: 0.0534
# Epoch 36/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0555 - val_loss: 0.0535
# Epoch 37/100
# 8/8 [==============================] - 3s 395ms/step - loss: 0.0555 - val_loss: 0.0534
# Epoch 38/100
# 8/8 [==============================] - 4s 549ms/step - loss: 0.0554 - val_loss: 0.0534
# Epoch 39/100
# 8/8 [==============================] - 3s 386ms/step - loss: 0.0555 - val_loss: 0.0535
# Epoch 40/100
# 8/8 [==============================] - 3s 396ms/step - loss: 0.0553 - val_loss: 0.0534
# Epoch 41/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0554 - val_loss: 0.0536
# Epoch 42/100
# 8/8 [==============================] - 4s 568ms/step - loss: 0.0553 - val_loss: 0.0532
# Epoch 43/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0558 - val_loss: 0.0540
# Epoch 44/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0556 - val_loss: 0.0537
# Epoch 45/100
# 8/8 [==============================] - 3s 386ms/step - loss: 0.0555 - val_loss: 0.0538
# Epoch 46/100
# 8/8 [==============================] - 4s 542ms/step - loss: 0.0553 - val_loss: 0.0533
# Epoch 47/100
# 8/8 [==============================] - 3s 402ms/step - loss: 0.0551 - val_loss: 0.0532
# Epoch 48/100
# 8/8 [==============================] - 3s 383ms/step - loss: 0.0551 - val_loss: 0.0534
# Epoch 49/100
# 8/8 [==============================] - 3s 401ms/step - loss: 0.0552 - val_loss: 0.0532
# Epoch 50/100
# 8/8 [==============================] - 4s 513ms/step - loss: 0.0552 - val_loss: 0.0533
# Epoch 51/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.0553 - val_loss: 0.0533
# Epoch 52/100
# 8/8 [==============================] - 3s 387ms/step - loss: 0.0551 - val_loss: 0.0531
# Epoch 53/100
# 8/8 [==============================] - 4s 453ms/step - loss: 0.0552 - val_loss: 0.0532
# Epoch 54/100
# 8/8 [==============================] - 4s 471ms/step - loss: 0.0551 - val_loss: 0.0532
# Epoch 55/100
# 8/8 [==============================] - 3s 404ms/step - loss: 0.0549 - val_loss: 0.0532
# Epoch 56/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0550 - val_loss: 0.0532
# Epoch 57/100
# 8/8 [==============================] - 4s 520ms/step - loss: 0.0550 - val_loss: 0.0537
# Epoch 58/100
# 8/8 [==============================] - 4s 510ms/step - loss: 0.0555 - val_loss: 0.0535
# Epoch 59/100
# 8/8 [==============================] - 6s 804ms/step - loss: 0.0552 - val_loss: 0.0532
# Epoch 60/100
# 8/8 [==============================] - 8s 961ms/step - loss: 0.0553 - val_loss: 0.0541
# Epoch 61/100
# 8/8 [==============================] - 7s 888ms/step - loss: 0.0554 - val_loss: 0.0532
# Epoch 62/100
# 8/8 [==============================] - 8s 815ms/step - loss: 0.0552 - val_loss: 0.0531
# Epoch 63/100
# 8/8 [==============================] - 5s 565ms/step - loss: 0.0548 - val_loss: 0.0531
# Epoch 64/100
# 8/8 [==============================] - 6s 836ms/step - loss: 0.0549 - val_loss: 0.0532
# Epoch 65/100
# 8/8 [==============================] - 5s 618ms/step - loss: 0.0550 - val_loss: 0.0531
# Epoch 66/100
# 8/8 [==============================] - 6s 802ms/step - loss: 0.0550 - val_loss: 0.0533
# Epoch 67/100
# 8/8 [==============================] - 5s 633ms/step - loss: 0.0548 - val_loss: 0.0530
# Epoch 68/100
# 8/8 [==============================] - 6s 811ms/step - loss: 0.0550 - val_loss: 0.0533
# Epoch 69/100
# 8/8 [==============================] - 5s 551ms/step - loss: 0.0547 - val_loss: 0.0532
# Epoch 70/100
# 8/8 [==============================] - 5s 667ms/step - loss: 0.0549 - val_loss: 0.0529
# Epoch 71/100
# 8/8 [==============================] - 6s 805ms/step - loss: 0.0549 - val_loss: 0.0539
# Epoch 72/100
# 8/8 [==============================] - 4s 421ms/step - loss: 0.0549 - val_loss: 0.0530
# Epoch 73/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0545 - val_loss: 0.0529
# Epoch 74/100
# 8/8 [==============================] - 4s 505ms/step - loss: 0.0548 - val_loss: 0.0534
# Epoch 75/100
# 8/8 [==============================] - 6s 729ms/step - loss: 0.0548 - val_loss: 0.0530
# Epoch 76/100
# 8/8 [==============================] - 7s 920ms/step - loss: 0.0551 - val_loss: 0.0530
# Epoch 77/100
# 8/8 [==============================] - 7s 938ms/step - loss: 0.0550 - val_loss: 0.0532
# Epoch 78/100
# 8/8 [==============================] - 5s 609ms/step - loss: 0.0547 - val_loss: 0.0533
# Epoch 79/100
# 8/8 [==============================] - 6s 589ms/step - loss: 0.0546 - val_loss: 0.0529
# Epoch 80/100
# 8/8 [==============================] - 4s 545ms/step - loss: 0.0545 - val_loss: 0.0528
# Epoch 81/100
# 8/8 [==============================] - 4s 491ms/step - loss: 0.0546 - val_loss: 0.0532
# Epoch 82/100
# 8/8 [==============================] - 4s 463ms/step - loss: 0.0546 - val_loss: 0.0525
# Epoch 83/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.0543 - val_loss: 0.0525
# Epoch 84/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0547 - val_loss: 0.0531
# Epoch 85/100
# 8/8 [==============================] - 4s 514ms/step - loss: 0.0548 - val_loss: 0.0543
# Epoch 86/100
# 8/8 [==============================] - 3s 415ms/step - loss: 0.0549 - val_loss: 0.0528
# Epoch 87/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0546 - val_loss: 0.0533
# Epoch 88/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0547 - val_loss: 0.0528
# Epoch 89/100
# 8/8 [==============================] - 4s 524ms/step - loss: 0.0546 - val_loss: 0.0527
# Epoch 90/100
# 8/8 [==============================] - 3s 404ms/step - loss: 0.0544 - val_loss: 0.0526
# Epoch 91/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0544 - val_loss: 0.0527
# Epoch 92/100
# 8/8 [==============================] - 3s 396ms/step - loss: 0.0544 - val_loss: 0.0526
# Epoch 93/100
# 8/8 [==============================] - 4s 549ms/step - loss: 0.0547 - val_loss: 0.0535
# Epoch 94/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.0553 - val_loss: 0.0531
# Epoch 95/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0547 - val_loss: 0.0531
# Epoch 96/100
# 8/8 [==============================] - 3s 396ms/step - loss: 0.0545 - val_loss: 0.0528
# Epoch 97/100
# 8/8 [==============================] - 4s 567ms/step - loss: 0.0543 - val_loss: 0.0525
# Epoch 98/100
# 8/8 [==============================] - 3s 396ms/step - loss: 0.0543 - val_loss: 0.0525
# Epoch 99/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0541 - val_loss: 0.0525
# Epoch 100/100
# 8/8 [==============================] - 3s 400ms/step - loss: 0.0539 - val_loss: 0.0524

# %%
y_pred = model.predict(X_test)

y_test_original = scaler.inverse_transform(y_test)
y_pred_original = scaler.inverse_transform(y_pred)

parameters = ['K_x', 'K_y', 'sigma_x', 'sigma_y', 'pho']
# Tracer le vecteur prédit
for i, parameter in enumerate(parameters):
    fig, axs = plt.subplots(2)  # Créer 2 subplots
    fig.suptitle('Predicted vector for parameter {}'.format(parameter))

    # Tracer le vecteur global
    axs[0].plot(y_test_original[:, i], c='b', label='Real values')
    axs[0].plot(y_pred_original[:, i], c='r', label='Predictions')
    axs[0].set_ylabel('Value')
    axs[0].legend()

    # Tracer le vecteur zoomé
    ind = np.random.randint(0,1938)
    x = np.arange(ind, ind+60)  # Créer un tableau d'indices
    axs[1].plot(x, y_test_original[ind:ind+60, i], c='b', label='Real values')
    axs[1].plot(x, y_pred_original[ind:ind+60, i], c='r', label='Predictions')
    axs[1].set_xlabel('Index')
    axs[1].set_ylabel('Value')
    axs[1].legend()
    print()

    plt.show()
# Out:
# 63/63 [==============================] - 1s 10ms/step

# %%
results = model.evaluate(X_test, y_test, batch_size=1000)
print("test loss", results)
# Out:
# 2/2 [==============================] - 1s 179ms/step - loss: 0.0524
# test loss 0.052398260682821274

# %%
plt.figure()
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Training and validation loss - Cov ZC')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
MSE = np.mean((y_test_original - y_pred_original)**2, axis = 0)
M = ["{:.1e}".format(x) for x in MSE] # format scientifique
Cal = {'Parameters': parameters,
        'MSE': M}

# Create DataFrame
Cal_table = pd.DataFrame(Cal).transpose()

# %%
MSE
# Out:
# array([0.00047794, 0.00071863, 0.00095631, 0.00097116, 0.1516971 ])

# %%
Cal_table
# Out:
#                   0        1        2        3        4
# Parameters      K_x      K_y  sigma_x  sigma_y      pho
# MSE         4.8e-04  7.2e-04  9.6e-04  9.7e-04  1.5e-01

# %% [markdown]
# ***2.2: Corr FWD***

# %%
from tqdm import tqdm

X_corr = np.zeros((len(result), len(maturity_corr)))
for k in tqdm(range(len(result))):
    para = result[k]
    l_corr = []

    for i in range(len(maturity_corr)):
      T_i, T_j = maturity_corr[i]
      l_corr.append(corr(X_FWD, Y_FWD, T_i, T_j, para))
    X_corr[k] = l_corr
# Out:
# 100%|██████████| 10000/10000 [00:37<00:00, 266.17it/s]

# %%
print(X_corr.shape)
# Out:
# (10000, 66)

# %%
X_corr[:1,:]
# Out:
# array([[1.        , 0.99993962, 0.99975921, 0.99946003, 0.99904347,
#         0.99851111, 0.99786466, 0.99710599, 0.9962371 , 0.99526011,
#         0.9941773 , 1.        , 0.99993998, 0.99976076, 0.99946368,
#         0.99905026, 0.99852217, 0.99788122, 0.99712937, 0.9962687 ,
#         0.99530143, 1.        , 0.99994039, 0.99976246, 0.99946767,
#         0.99905764, 0.99853413, 0.99789906, 0.99715445, 0.99630248,
#         1.        , 0.99994084, 0.99976431, 0.99947199, 0.99906558,
#         0.99854696, 0.99791811, 0.99718115, 1.        , 0.99994131,
#         0.9997663 , 0.99947661, 0.99907407, 0.99856062, 0.99793833,
#         1.        , 0.99994183, 0.99976842, 0.99948154, 0.99908308,
#         0.99857507, 1.        , 0.99994238, 0.99977067, 0.99948675,
#         0.99909258, 1.        , 0.99994296, 0.99977305, 0.99949223,
#         1.        , 0.99994357, 0.99977555, 1.        , 0.9999442 ,
#         1.        ]])

# %%
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_corr, y, test_size=0.2, random_state=42)

scaler2 = MinMaxScaler()
X_train2 = scaler2.fit_transform(X_train2)
X_test2 = scaler2.transform(X_test2)
y_train2 = scaler2.fit_transform(y_train2)
y_test2= scaler2.transform(y_test2)

# %%
print(X_train2[:,0])
y_train2[0,:]
# Out:
# [0.328125   0.33203125 0.328125   ... 0.328125   0.328125   0.33203125]
# array([0.77102954, 0.14675095, 0.94939086, 0.46162236, 0.30004622])

# %%
print(X_train2.shape)
print(y_train2.shape)

print(X_test2.shape)
print(y_test2.shape)
# Out:
# (8000, 66)
# (8000, 5)
# (2000, 66)
# (2000, 5)

# %%
# Définir le modèle
model2 = tf.keras.Sequential([
    layers.Dense(1000, activation='relu', input_shape=(66,)),  # Couche d'entrée
    layers.Dense(1500, activation='relu'),  # Première couche cachée
    layers.Dense(1000, activation='relu'),  # Deuxième couche cachée
    layers.Dropout(0.25),  # Dropout
    layers.Dense(5)  # Couche de sortie
])

# Compiler le modèle
model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='mse')

# Entraîner le modèle
history2 = model2.fit(X_train2, y_train2, epochs=100, batch_size=1000, validation_data=(X_test2, y_test2))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 5s 582ms/step - loss: 0.3634 - val_loss: 0.0919
# Epoch 2/100
# 8/8 [==============================] - 3s 406ms/step - loss: 0.0982 - val_loss: 0.0886
# Epoch 3/100
# 8/8 [==============================] - 3s 395ms/step - loss: 0.0891 - val_loss: 0.0823
# Epoch 4/100
# 8/8 [==============================] - 3s 400ms/step - loss: 0.0869 - val_loss: 0.0823
# Epoch 5/100
# 8/8 [==============================] - 4s 558ms/step - loss: 0.0857 - val_loss: 0.0822
# Epoch 6/100
# 8/8 [==============================] - 3s 397ms/step - loss: 0.0856 - val_loss: 0.0820
# Epoch 7/100
# 8/8 [==============================] - 3s 402ms/step - loss: 0.0847 - val_loss: 0.0819
# Epoch 8/100
# 8/8 [==============================] - 3s 422ms/step - loss: 0.0846 - val_loss: 0.0816
# Epoch 9/100
# 8/8 [==============================] - 4s 505ms/step - loss: 0.0848 - val_loss: 0.0819
# Epoch 10/100
# 8/8 [==============================] - 3s 399ms/step - loss: 0.0845 - val_loss: 0.0811
# Epoch 11/100
# 8/8 [==============================] - 3s 397ms/step - loss: 0.0843 - val_loss: 0.0808
# Epoch 12/100
# 8/8 [==============================] - 4s 503ms/step - loss: 0.0840 - val_loss: 0.0809
# Epoch 13/100
# 8/8 [==============================] - 4s 447ms/step - loss: 0.0836 - val_loss: 0.0825
# Epoch 14/100
# 8/8 [==============================] - 3s 400ms/step - loss: 0.0836 - val_loss: 0.0809
# Epoch 15/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.0828 - val_loss: 0.0801
# Epoch 16/100
# 8/8 [==============================] - 4s 546ms/step - loss: 0.0832 - val_loss: 0.0805
# Epoch 17/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0843 - val_loss: 0.0811
# Epoch 18/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.0834 - val_loss: 0.0804
# Epoch 19/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0829 - val_loss: 0.0803
# Epoch 20/100
# 8/8 [==============================] - 4s 556ms/step - loss: 0.0828 - val_loss: 0.0801
# Epoch 21/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0824 - val_loss: 0.0800
# Epoch 22/100
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0823 - val_loss: 0.0798
# Epoch 23/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0823 - val_loss: 0.0810
# Epoch 24/100
# 8/8 [==============================] - 4s 563ms/step - loss: 0.0824 - val_loss: 0.0846
# Epoch 25/100
# 8/8 [==============================] - 3s 397ms/step - loss: 0.0848 - val_loss: 0.0807
# Epoch 26/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0835 - val_loss: 0.0810
# Epoch 27/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0830 - val_loss: 0.0804
# Epoch 28/100
# 8/8 [==============================] - 4s 558ms/step - loss: 0.0827 - val_loss: 0.0801
# Epoch 29/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0828 - val_loss: 0.0804
# Epoch 30/100
# 8/8 [==============================] - 3s 414ms/step - loss: 0.0825 - val_loss: 0.0797
# Epoch 31/100
# 8/8 [==============================] - 3s 448ms/step - loss: 0.0821 - val_loss: 0.0796
# Epoch 32/100
# 8/8 [==============================] - 4s 501ms/step - loss: 0.0816 - val_loss: 0.0794
# Epoch 33/100
# 8/8 [==============================] - 3s 396ms/step - loss: 0.0815 - val_loss: 0.0806
# Epoch 34/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0830 - val_loss: 0.0794
# Epoch 35/100
# 8/8 [==============================] - 4s 510ms/step - loss: 0.0819 - val_loss: 0.0811
# Epoch 36/100
# 8/8 [==============================] - 4s 430ms/step - loss: 0.0818 - val_loss: 0.0793
# Epoch 37/100
# 8/8 [==============================] - 3s 393ms/step - loss: 0.0819 - val_loss: 0.0788
# Epoch 38/100
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0809 - val_loss: 0.0790
# Epoch 39/100
# 8/8 [==============================] - 4s 592ms/step - loss: 0.0810 - val_loss: 0.0785
# Epoch 40/100
# 8/8 [==============================] - 3s 400ms/step - loss: 0.0820 - val_loss: 0.0794
# Epoch 41/100
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0813 - val_loss: 0.0786
# Epoch 42/100
# 8/8 [==============================] - 3s 399ms/step - loss: 0.0821 - val_loss: 0.0794
# Epoch 43/100
# 8/8 [==============================] - 4s 566ms/step - loss: 0.0809 - val_loss: 0.0785
# Epoch 44/100
# 8/8 [==============================] - 3s 403ms/step - loss: 0.0812 - val_loss: 0.0791
# Epoch 45/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0828 - val_loss: 0.0787
# Epoch 46/100
# 8/8 [==============================] - 3s 403ms/step - loss: 0.0824 - val_loss: 0.0798
# Epoch 47/100
# 8/8 [==============================] - 4s 538ms/step - loss: 0.0817 - val_loss: 0.0818
# Epoch 48/100
# 8/8 [==============================] - 3s 397ms/step - loss: 0.0820 - val_loss: 0.0805
# Epoch 49/100
# 8/8 [==============================] - 3s 395ms/step - loss: 0.0818 - val_loss: 0.0797
# Epoch 50/100
# 8/8 [==============================] - 4s 461ms/step - loss: 0.0815 - val_loss: 0.0791
# Epoch 51/100
# 8/8 [==============================] - 4s 468ms/step - loss: 0.0810 - val_loss: 0.0788
# Epoch 52/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0808 - val_loss: 0.0786
# Epoch 53/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0806 - val_loss: 0.0787
# Epoch 54/100
# 8/8 [==============================] - 4s 514ms/step - loss: 0.0823 - val_loss: 0.0797
# Epoch 55/100
# 8/8 [==============================] - 3s 414ms/step - loss: 0.0812 - val_loss: 0.0805
# Epoch 56/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0809 - val_loss: 0.0785
# Epoch 57/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0804 - val_loss: 0.0788
# Epoch 58/100
# 8/8 [==============================] - 4s 547ms/step - loss: 0.0800 - val_loss: 0.0782
# Epoch 59/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0851 - val_loss: 0.0850
# Epoch 60/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0851 - val_loss: 0.0819
# Epoch 61/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0834 - val_loss: 0.0808
# Epoch 62/100
# 8/8 [==============================] - 4s 554ms/step - loss: 0.0826 - val_loss: 0.0806
# Epoch 63/100
# 8/8 [==============================] - 3s 386ms/step - loss: 0.0820 - val_loss: 0.0800
# Epoch 64/100
# 8/8 [==============================] - 3s 386ms/step - loss: 0.0816 - val_loss: 0.0798
# Epoch 65/100
# 8/8 [==============================] - 3s 388ms/step - loss: 0.0814 - val_loss: 0.0796
# Epoch 66/100
# 8/8 [==============================] - 4s 554ms/step - loss: 0.0814 - val_loss: 0.0792
# Epoch 67/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0812 - val_loss: 0.0792
# Epoch 68/100
# 8/8 [==============================] - 3s 395ms/step - loss: 0.0809 - val_loss: 0.0794
# Epoch 69/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0809 - val_loss: 0.0785
# Epoch 70/100
# 8/8 [==============================] - 4s 556ms/step - loss: 0.0807 - val_loss: 0.0786
# Epoch 71/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.0808 - val_loss: 0.0785
# Epoch 72/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0808 - val_loss: 0.0815
# Epoch 73/100
# 8/8 [==============================] - 3s 408ms/step - loss: 0.0827 - val_loss: 0.0788
# Epoch 74/100
# 8/8 [==============================] - 4s 525ms/step - loss: 0.0811 - val_loss: 0.0790
# Epoch 75/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.0808 - val_loss: 0.0787
# Epoch 76/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0804 - val_loss: 0.0790
# Epoch 77/100
# 8/8 [==============================] - 3s 433ms/step - loss: 0.0808 - val_loss: 0.0794
# Epoch 78/100
# 8/8 [==============================] - 4s 497ms/step - loss: 0.0807 - val_loss: 0.0788
# Epoch 79/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0802 - val_loss: 0.0781
# Epoch 80/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0802 - val_loss: 0.0793
# Epoch 81/100
# 8/8 [==============================] - 4s 505ms/step - loss: 0.0805 - val_loss: 0.0795
# Epoch 82/100
# 8/8 [==============================] - 4s 430ms/step - loss: 0.0802 - val_loss: 0.0781
# Epoch 83/100
# 8/8 [==============================] - 3s 401ms/step - loss: 0.0808 - val_loss: 0.0781
# Epoch 84/100
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0803 - val_loss: 0.0781
# Epoch 85/100
# 8/8 [==============================] - 5s 591ms/step - loss: 0.0802 - val_loss: 0.0779
# Epoch 86/100
# 8/8 [==============================] - 3s 401ms/step - loss: 0.0796 - val_loss: 0.0779
# Epoch 87/100
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0820 - val_loss: 0.0812
# Epoch 88/100
# 8/8 [==============================] - 3s 395ms/step - loss: 0.0813 - val_loss: 0.0787
# Epoch 89/100
# 8/8 [==============================] - 4s 569ms/step - loss: 0.0805 - val_loss: 0.0797
# Epoch 90/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.0807 - val_loss: 0.0786
# Epoch 91/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0822 - val_loss: 0.0817
# Epoch 92/100
# 8/8 [==============================] - 3s 407ms/step - loss: 0.0818 - val_loss: 0.0800
# Epoch 93/100
# 8/8 [==============================] - 4s 532ms/step - loss: 0.0807 - val_loss: 0.0785
# Epoch 94/100
# 8/8 [==============================] - 3s 404ms/step - loss: 0.0802 - val_loss: 0.0782
# Epoch 95/100
# 8/8 [==============================] - 3s 401ms/step - loss: 0.0801 - val_loss: 0.0780
# Epoch 96/100
# 8/8 [==============================] - 4s 487ms/step - loss: 0.0798 - val_loss: 0.0781
# Epoch 97/100
# 8/8 [==============================] - 4s 450ms/step - loss: 0.0800 - val_loss: 0.0782
# Epoch 98/100
# 8/8 [==============================] - 3s 393ms/step - loss: 0.0801 - val_loss: 0.0786
# Epoch 99/100
# 8/8 [==============================] - 3s 396ms/step - loss: 0.0826 - val_loss: 0.0781
# Epoch 100/100
# 8/8 [==============================] - 4s 556ms/step - loss: 0.0811 - val_loss: 0.0791

# %%
y_pred2 = model2.predict(X_test2)

y_test_original2 = scaler2.inverse_transform(y_test2)
y_pred_original2 = scaler2.inverse_transform(y_pred2)


# Tracer le vecteur prédit
for i, parameter in enumerate(parameters):
    fig, axs = plt.subplots(2)  # Créer 2 subplots
    fig.suptitle('Predicted vector for parameter {}'.format(parameter))

    # Tracer le vecteur global
    axs[0].plot(y_test_original2[:, i], c='b', label='Real values')
    axs[0].plot(y_pred_original2[:, i], c='r', label='Predictions')
    axs[0].set_ylabel('Value')
    axs[0].legend()

    # Tracer le vecteur zoomé
    ind = np.random.randint(0,1938)
    x = np.arange(ind, ind+60)  # Créer un tableau d'indices
    axs[1].plot(x, y_test_original2[ind:ind+60, i], c='b', label='Real values')
    axs[1].plot(x, y_pred_original2[ind:ind+60, i], c='r', label='Predictions')
    axs[1].set_xlabel('Index')
    axs[1].set_ylabel('Value')
    axs[1].legend()
    print()

    plt.show()
# Out:
# 63/63 [==============================] - 1s 10ms/step

# %%
results2 = model2.evaluate(X_test2, y_test2, batch_size=1000)
print("test loss", results2)

plt.figure()
plt.plot(history2.history['loss'], label='Training loss')
plt.plot(history2.history['val_loss'], label='Validation loss')
plt.title('Training and validation loss - Corr FWD')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 129ms/step - loss: 0.0791
# test loss 0.07914694398641586

# %%
MSE2 = np.mean((y_test_original2 - y_pred_original2)**2, axis = 0)
M2 = ["{:.1e}".format(x) for x in MSE2] # format scientifique
Cal2 = {'Parameters': parameters,
        'MSE': M2}

# Create DataFrame
Cal_table2 = pd.DataFrame(Cal2).transpose()

Cal_table2
# Out:
#                   0        1        2        3        4
# Parameters      K_x      K_y  sigma_x  sigma_y      pho
# MSE         7.5e-04  1.1e-03  1.3e-03  1.3e-03  2.9e-01

# %%
Cal_table
# Out:
#                   0        1        2        3        4
# Parameters      K_x      K_y  sigma_x  sigma_y      pho
# MSE         4.8e-04  7.2e-04  9.6e-04  9.7e-04  1.5e-01

# %% [markdown]
# #3 Methode Direct

# %%
# Initialisation

def V(t,T, para):
  K_x, K_y, sigma_x, sigma_y, pho = para
  T_ = T - t
  a = T_ + (2/K_x)*np.exp(-K_x*T_) - (0.5/K_x)*np.exp(-2*K_x*T_) - 1.5/K_x
  b = T_ + (2/K_y)*np.exp(-K_y*T_) - (0.5/K_y)*np.exp(-2*K_y*T_) - 1.5/K_y
  K_ = K_x + K_y
  coeff = 2*pho*(sigma_x*sigma_y)/(K_x * K_y)
  c = T_ + (np.exp(-K_x*T_) - 1)/K_x + (np.exp(-K_y*T_) - 1)/K_y - (np.exp(-K_*T_) - 1)/K_
  return (sigma_x/K_x)**2 * a + (sigma_y/K_y)**2 * b + coeff * c

def V2(t,T,para):
  return 0.5/T * (V(t,T,para) - V(0,T,para) + V(0,t,para) )

def E_ZC(para, PM):
  mat = np.zeros((len(nb_step), len(nb_tenors)))
  for i in range(len(nb_step)):
    t_i = nb_step[i]
    for j in range(len(nb_tenors)):
      T_j = nb_tenors[j]
      mat[i,j] = 1/T_j * np.log(PM[j]/PM_interpolated[i]) - V2(t_i,T_j, para)
  return mat

# %%
nb_step = np.array([i for i in range(106)])*7/365
nb_tenors = np.array([3/12, 6/12, 9/12]+[i for i in range(1,21)]+[25,30])

# Données fournies
data = {
    '3 months': 3.837466,
    '6 months': 3.652828,
    '9 months': 3.488389,
    '1 year': 3.342178,
    '2 years': 2.906372,
    '3 years': 2.646339,
    '4 years': 2.501166,
    '5 years': 2.430029,
    '6 years': 2.405642,
    '7 years': 2.409838,
    '8 years': 2.430593,
    '9 years': 2.460012,
    '10 years': 2.492977,
    '11 years': 2.526227,
    '12 years': 2.557748,
    '13 years': 2.586349,
    '14 years': 2.611389,
    '15 years': 2.632583,
    '16 years': 2.649877,
    '17 years': 2.663360,
    '18 years': 2.673214,
    '19 years': 2.679666,
    '20 years': 2.682971,
    '25 years': 2.661341,
    '30 years': 2.596751
}

# Extraire uniquement les valeurs de droite (floats)
values = list(data.values())

# Convertir en tableau NumPy
PM = np.array(values)

print(PM)

# Interpoler les valeurs de PM pour les nb_step
PM_interpolated = np.interp(nb_step, np.arange(len(PM)), PM) # valeurs de PM les 106 premieres semaines
# Out:
# [3.837466 3.652828 3.488389 3.342178 2.906372 2.646339 2.501166 2.430029
#  2.405642 2.409838 2.430593 2.460012 2.492977 2.526227 2.557748 2.586349
#  2.611389 2.632583 2.649877 2.66336  2.673214 2.679666 2.682971 2.661341
#  2.596751]

# %%
print(nb_tenors.shape) # T_j, dataset de maturité T, nombre de col de X
print(PM.shape) # PM associé à T_j
print(nb_step.shape) # nombre de step de propagation, 2 ans de maturité t_i, nombre de lignes de X
print(PM_interpolated.shape) # PM associé à chaque t_j
# Out:
# (25,)
# (25,)
# (106,)
# (106,)

# %% [markdown]
# Lien des datas suivantes: https://www.ecb.europa.eu/stats/financial_markets_and_interest_rates/euro_area_yield_curves/html/index.en.html

# %%
plt.plot(nb_tenors,PM)
plt.xlabel('Years')
plt.ylabel('Yield in %')
plt.title('Euro area yield curves as of 27 February 2024')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
np.random.seed(0)
index = np.random.randint(0,len(result))
para = result[ind]

mat = E_ZC(para, PM)

test_week = [0,25,50,75,105]

print('Parameters: ', para)
for i in test_week:
  plt.plot(mat[i,:], label = 'DATE = WEEK_{}'.format(i))
  plt.xlabel('Years')
  plt.ylabel('ZC')
  plt.title('Expecation ZC for random set of parameters')
  plt.legend()
plt.show()
# Out:
# Parameters:  [0.02443859 0.10545392 0.09079726 0.07812251 0.88552168]

# %%
X_direct = np.zeros((2000,nb_step.shape[0],nb_tenors.shape[0]))

# %%
X_direct.shape
# Out:
# (2000, 106, 25)

# %%
E_ZC(result[0], PM)
# Out:
# array([[ 3.04647309e-14, -9.86211816e-02, -1.27162971e-01, ...,
#         -1.78943745e-02, -1.46392849e-02, -1.30183735e-02],
#        [ 3.72911210e-03, -9.67001879e-02, -1.25820446e-01, ...,
#         -1.68453157e-02, -1.36220970e-02, -1.20532516e-02],
#        [ 7.45561535e-03, -9.47833637e-02, -1.24482518e-01, ...,
#         -1.57971661e-02, -1.26054893e-02, -1.10885016e-02],
#        ...,
#        [ 3.61380184e-01,  7.07254120e-02, -1.87843717e-02, ...,
#          8.40458105e-02,  8.60160543e-02,  8.35564812e-02],
#        [ 3.64939389e-01,  7.22020905e-02, -1.79663257e-02, ...,
#          8.49650068e-02,  8.69445443e-02,  8.44594870e-02],
#        [ 3.68226050e-01,  7.35383038e-02, -1.72445912e-02, ...,
#          8.58791412e-02,  8.78691316e-02,  8.53593581e-02]])

# %%
from tqdm import tqdm

for i in tqdm(range(X_direct.shape[0])):
  X_direct[i] = E_ZC(result[i], PM)
# Out:
# 100%|██████████| 2000/2000 [04:25<00:00,  7.54it/s]

# %%
print(X_direct.shape)
# Out:
# (2000, 106, 25)

# %%
X_direct = X_direct.reshape(-1, X_direct.shape[1],X_direct.shape[2], 1)

print(X_direct.shape)
# Out:
# (2000, 106, 25, 1)

# %%
y = result
print(y.shape)
y_ = y[:X_direct.shape[0],]
y_.shape
# Out:
# (10000, 5)
# (2000, 5)

# %%
from sklearn.model_selection import train_test_split

X_train3, X_test3, y_train3, y_test3 = train_test_split(X_direct, y_, test_size = 0.2, random_state = 0)

# %%
print(X_train3.shape)
print(y_train3.shape)
# Out:
# (1600, 106, 25, 1)
# (1600, 5)

# %%
y_train3[0]
# Out:
# array([0.0710253 , 0.08600714, 0.07397423, 0.12832928, 0.24059118])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
y_train3 = scaler.fit_transform(y_train3)
y_test3= scaler.transform(y_test3)

# %%
y_train3[0]
# Out:
# array([0.49111904, 0.47235209, 0.33595984, 0.76681454, 0.6197442 ])

# %%
cnn = tf.keras.Sequential([
    layers.Conv2D(filters=7,kernel_size=7,activation='relu',input_shape=[106, 25, 1], padding='valid'),
    layers.MaxPooling2D(pool_size=2,strides=2),
    layers.Flatten(),


    layers.Dense(100, activation='relu',),  # Couche d'entrée du NN
    layers.Dropout(0.25),  # Dropout
    layers.Dense(5)  # Couche de sortie
])


# Compiler le modèle
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002),
              loss='mse')

# Entraîner le modèle
history = cnn.fit(X_train3, y_train3, epochs=100, batch_size=200, validation_data=(X_test3, y_test3))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 3s 263ms/step - loss: 0.2433 - val_loss: 0.1643
# Epoch 2/100
# 8/8 [==============================] - 2s 229ms/step - loss: 0.1299 - val_loss: 0.0900
# Epoch 3/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0955 - val_loss: 0.0807
# Epoch 4/100
# 8/8 [==============================] - 2s 237ms/step - loss: 0.0939 - val_loss: 0.0768
# Epoch 5/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0871 - val_loss: 0.0768
# Epoch 6/100
# 8/8 [==============================] - 3s 362ms/step - loss: 0.0867 - val_loss: 0.0768
# Epoch 7/100
# 8/8 [==============================] - 2s 265ms/step - loss: 0.0854 - val_loss: 0.0757
# Epoch 8/100
# 8/8 [==============================] - 3s 338ms/step - loss: 0.0837 - val_loss: 0.0746
# Epoch 9/100
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0836 - val_loss: 0.0738
# Epoch 10/100
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0842 - val_loss: 0.0740
# Epoch 11/100
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0831 - val_loss: 0.0731
# Epoch 12/100
# 8/8 [==============================] - 3s 384ms/step - loss: 0.0823 - val_loss: 0.0729
# Epoch 13/100
# 8/8 [==============================] - 2s 244ms/step - loss: 0.0812 - val_loss: 0.0728
# Epoch 14/100
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0814 - val_loss: 0.0723
# Epoch 15/100
# 8/8 [==============================] - 2s 238ms/step - loss: 0.0799 - val_loss: 0.0720
# Epoch 16/100
# 8/8 [==============================] - 2s 283ms/step - loss: 0.0800 - val_loss: 0.0717
# Epoch 17/100
# 8/8 [==============================] - 2s 313ms/step - loss: 0.0795 - val_loss: 0.0718
# Epoch 18/100
# 8/8 [==============================] - 3s 404ms/step - loss: 0.0791 - val_loss: 0.0713
# Epoch 19/100
# 8/8 [==============================] - 2s 294ms/step - loss: 0.0797 - val_loss: 0.0711
# Epoch 20/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.0783 - val_loss: 0.0708
# Epoch 21/100
# 8/8 [==============================] - 3s 348ms/step - loss: 0.0774 - val_loss: 0.0705
# Epoch 22/100
# 8/8 [==============================] - 3s 446ms/step - loss: 0.0793 - val_loss: 0.0703
# Epoch 23/100
# 8/8 [==============================] - 3s 368ms/step - loss: 0.0776 - val_loss: 0.0700
# Epoch 24/100
# 8/8 [==============================] - 2s 238ms/step - loss: 0.0771 - val_loss: 0.0697
# Epoch 25/100
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0759 - val_loss: 0.0692
# Epoch 26/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0765 - val_loss: 0.0689
# Epoch 27/100
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0756 - val_loss: 0.0684
# Epoch 28/100
# 8/8 [==============================] - 2s 280ms/step - loss: 0.0738 - val_loss: 0.0684
# Epoch 29/100
# 8/8 [==============================] - 3s 329ms/step - loss: 0.0752 - val_loss: 0.0678
# Epoch 30/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0749 - val_loss: 0.0672
# Epoch 31/100
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0732 - val_loss: 0.0671
# Epoch 32/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0746 - val_loss: 0.0663
# Epoch 33/100
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0723 - val_loss: 0.0660
# Epoch 34/100
# 8/8 [==============================] - 2s 236ms/step - loss: 0.0720 - val_loss: 0.0659
# Epoch 35/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.0718 - val_loss: 0.0650
# Epoch 36/100
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0719 - val_loss: 0.0651
# Epoch 37/100
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0717 - val_loss: 0.0644
# Epoch 38/100
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0702 - val_loss: 0.0641
# Epoch 39/100
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0705 - val_loss: 0.0638
# Epoch 40/100
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0694 - val_loss: 0.0631
# Epoch 41/100
# 8/8 [==============================] - 2s 313ms/step - loss: 0.0689 - val_loss: 0.0630
# Epoch 42/100
# 8/8 [==============================] - 2s 289ms/step - loss: 0.0695 - val_loss: 0.0634
# Epoch 43/100
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0681 - val_loss: 0.0629
# Epoch 44/100
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0680 - val_loss: 0.0621
# Epoch 45/100
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0687 - val_loss: 0.0621
# Epoch 46/100
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0686 - val_loss: 0.0620
# Epoch 47/100
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0683 - val_loss: 0.0621
# Epoch 48/100
# 8/8 [==============================] - 3s 379ms/step - loss: 0.0675 - val_loss: 0.0618
# Epoch 49/100
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0675 - val_loss: 0.0615
# Epoch 50/100
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0670 - val_loss: 0.0612
# Epoch 51/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0679 - val_loss: 0.0621
# Epoch 52/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0679 - val_loss: 0.0623
# Epoch 53/100
# 8/8 [==============================] - 2s 235ms/step - loss: 0.0672 - val_loss: 0.0614
# Epoch 54/100
# 8/8 [==============================] - 3s 337ms/step - loss: 0.0670 - val_loss: 0.0611
# Epoch 55/100
# 8/8 [==============================] - 2s 275ms/step - loss: 0.0671 - val_loss: 0.0612
# Epoch 56/100
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0671 - val_loss: 0.0618
# Epoch 57/100
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0674 - val_loss: 0.0617
# Epoch 58/100
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0662 - val_loss: 0.0610
# Epoch 59/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0667 - val_loss: 0.0613
# Epoch 60/100
# 8/8 [==============================] - 2s 270ms/step - loss: 0.0660 - val_loss: 0.0609
# Epoch 61/100
# 8/8 [==============================] - 3s 334ms/step - loss: 0.0657 - val_loss: 0.0611
# Epoch 62/100
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0663 - val_loss: 0.0606
# Epoch 63/100
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0656 - val_loss: 0.0615
# Epoch 64/100
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0662 - val_loss: 0.0611
# Epoch 65/100
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0663 - val_loss: 0.0618
# Epoch 66/100
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0666 - val_loss: 0.0606
# Epoch 67/100
# 8/8 [==============================] - 3s 359ms/step - loss: 0.0659 - val_loss: 0.0607
# Epoch 68/100
# 8/8 [==============================] - 2s 237ms/step - loss: 0.0662 - val_loss: 0.0611
# Epoch 69/100
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0653 - val_loss: 0.0609
# Epoch 70/100
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0653 - val_loss: 0.0610
# Epoch 71/100
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0659 - val_loss: 0.0607
# Epoch 72/100
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0655 - val_loss: 0.0604
# Epoch 73/100
# 8/8 [==============================] - 2s 270ms/step - loss: 0.0653 - val_loss: 0.0606
# Epoch 74/100
# 8/8 [==============================] - 3s 319ms/step - loss: 0.0655 - val_loss: 0.0607
# Epoch 75/100
# 8/8 [==============================] - 2s 224ms/step - loss: 0.0655 - val_loss: 0.0605
# Epoch 76/100
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0653 - val_loss: 0.0607
# Epoch 77/100
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0658 - val_loss: 0.0604
# Epoch 78/100
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0652 - val_loss: 0.0607
# Epoch 79/100
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0650 - val_loss: 0.0612
# Epoch 80/100
# 8/8 [==============================] - 3s 393ms/step - loss: 0.0657 - val_loss: 0.0609
# Epoch 81/100
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0655 - val_loss: 0.0606
# Epoch 82/100
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0653 - val_loss: 0.0612
# Epoch 83/100
# 8/8 [==============================] - 2s 237ms/step - loss: 0.0650 - val_loss: 0.0603
# Epoch 84/100
# 8/8 [==============================] - 3s 354ms/step - loss: 0.0644 - val_loss: 0.0609
# Epoch 85/100
# 8/8 [==============================] - 2s 234ms/step - loss: 0.0646 - val_loss: 0.0603
# Epoch 86/100
# 8/8 [==============================] - 3s 369ms/step - loss: 0.0650 - val_loss: 0.0606
# Epoch 87/100
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0647 - val_loss: 0.0604
# Epoch 88/100
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0650 - val_loss: 0.0605
# Epoch 89/100
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0648 - val_loss: 0.0604
# Epoch 90/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0642 - val_loss: 0.0603
# Epoch 91/100
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0644 - val_loss: 0.0604
# Epoch 92/100
# 8/8 [==============================] - 2s 325ms/step - loss: 0.0647 - val_loss: 0.0603
# Epoch 93/100
# 8/8 [==============================] - 2s 274ms/step - loss: 0.0640 - val_loss: 0.0607
# Epoch 94/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0645 - val_loss: 0.0601
# Epoch 95/100
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0640 - val_loss: 0.0601
# Epoch 96/100
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0641 - val_loss: 0.0602
# Epoch 97/100
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0639 - val_loss: 0.0602
# Epoch 98/100
# 8/8 [==============================] - 2s 255ms/step - loss: 0.0645 - val_loss: 0.0601
# Epoch 99/100
# 8/8 [==============================] - 3s 347ms/step - loss: 0.0637 - val_loss: 0.0602
# Epoch 100/100
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0644 - val_loss: 0.0600

# %%
results = cnn.evaluate(X_test3, y_test3, batch_size=100)
print("test loss", results)
# Out:
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0600
# test loss 0.05997685343027115

# %%
y_pred3 = cnn.predict(X_test3)

y_test_original3 = scaler.inverse_transform(y_test3)
y_pred_original3 = scaler.inverse_transform(y_pred3)

parameters = ['K_x', 'K_y', 'sigma_x', 'sigma_y', 'pho']
# Tracer le vecteur prédit
for i, parameter in enumerate(parameters):
    fig, axs = plt.subplots(2)  # Créer 2 subplots
    fig.suptitle('Predicted vector for parameter {}'.format(parameter))

    # Tracer le vecteur global
    axs[0].plot(y_test_original3[:, i], c='b', label='Real values')
    axs[0].plot(y_pred_original3[:, i], c='r', label='Predictions')
    axs[0].set_ylabel('Value')
    axs[0].legend()

    # Tracer le vecteur zoomé
    ind = np.random.randint(0,y_test3.shape[0]-30)
    x = np.arange(ind, ind+30)  # Créer un tableau d'indices
    axs[1].plot(x, y_test_original3[ind:ind+30, i], c='b', label='Real values')
    axs[1].plot(x, y_pred_original3[ind:ind+30, i], c='r', label='Predictions')
    axs[1].set_xlabel('Index')
    axs[1].set_ylabel('Value')
    axs[1].legend()
    print()

    plt.show()
# Out:
# 13/13 [==============================] - 0s 14ms/step

# %%
plt.figure()
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Training and validation loss - Exp(ZC)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
MSE3 = np.mean((y_test_original3 - y_pred_original3)**2, axis = 0)
M3 = ["{:.1e}".format(x) for x in MSE2] # format scientifique
Cal3 = {'Parameters': parameters,
        'MSE': M3}

# Create DataFrame
Cal_table3 = pd.DataFrame(Cal3).transpose()
# Out:
#                   0        1        2        3        4
# Parameters      K_x      K_y  sigma_x  sigma_y      pho
# MSE         4.9e-04  8.5e-04  1.1e-03  1.1e-03  1.8e-01

# %% [markdown]
# #4 Final Results (MSE)

# %%
c1 = Cal_table.transpose()

# %%
c2 = Cal_table2.transpose()

# %%
c3 = Cal_table3.transpose()

# %%
for i in c2['MSE'].values:
  print(i)
# Out:
# 7.5e-04
# 1.1e-03
# 1.3e-03
# 1.3e-03
# 2.9e-01

# %%
l1 = [i for i in c1['MSE'].values]
l2 = [i for i in c2['MSE'].values]
l3 = [i for i in c3['MSE'].values]
na = ['COV ZC','CORR FWD','ZC']

l4 = [l1,l2,l3]
print(l4)

final_result = pd.DataFrame(l4, columns=['K_x', 'K_y', 'sigma_x', 'sigma_y', 'pho'])

final_result.insert(0, "MSE",na,True)
# Out:
# [['4.8e-04', '7.2e-04', '9.6e-04', '9.7e-04', '1.5e-01'], ['7.5e-04', '1.1e-03', '1.3e-03', '1.3e-03', '2.9e-01'], ['4.9e-04', '8.5e-04', '1.1e-03', '1.1e-03', '1.8e-01']]

# %%
final_result
# Out:
#         MSE      K_x      K_y  sigma_x  sigma_y      pho
# 0    COV ZC  4.8e-04  7.2e-04  9.6e-04  9.7e-04  1.5e-01
# 1  CORR FWD  7.5e-04  1.1e-03  1.3e-03  1.3e-03  2.9e-01
# 2        ZC  4.9e-04  8.5e-04  1.1e-03  1.1e-03  1.8e-01
